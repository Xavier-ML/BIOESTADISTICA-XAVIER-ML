# %% [markdown]
# <a href="https://colab.research.google.com/github/Xavier-ML/BIOESTADISTICA-XAVIER-ML/blob/main/Dia_7_CIBERTEC.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
#web scraping
import requests

# %%
# Pandas tarea
import pandas as pd

# %%
datos = pd.read_csv("/content/datos.csv", sep = "," )

# %% [markdown]
# P1. Cargar el dataset datos.csv en Pandas. Mostrar las filas iniciales iniciales en la pantalla. Cuantas filas y columnas hay.

# %%
datos.head(9)
# Out:
#    Unnamed: 0  age         workclass  fnlwgt  education  education-num  \
# 0           0   50  Self-emp-not-inc   83311  Bachelors             13
# 1           1   38           Private  215646    HS-grad              9
# 2           2   53           Private  234721       11th              7
# 3           3   28           Private  338409  Bachelors             13
# 4           4   37           Private  284582    Masters             14
# 5           5   49           Private  160187        9th              5
# 6           6   52  Self-emp-not-inc  209642    HS-grad              9
# 7           7   31           Private   45781    Masters             14
# 8           8   42           Private  159449  Bachelors             13
#
#           marital-status         occupation   relationship   race     sex  \
# 0     Married-civ-spouse    Exec-managerial        Husband  White    Male
# 1               Divorced  Handlers-cleaners  Not-in-family  White    Male
# ...

# %%
datos.shape
# Out:
# (32560, 16)

# %% [markdown]
# P2. ¿Cuántas perosnas de sexo masculino y femenino están representadas en el dataset?

# %%
grupoMaculino = datos[datos.sex == "Male"]
grupoMaculino.shape
# Out:
# (21789, 16)

# %%
grupoMujeres = datos[datos.sex == "Female"]
grupoMujeres.shape
# Out:
# (10771, 16)

# %%
21789 + 10771
# Out:
# 32560

# %% [markdown]
# P3. ¿Cuál es la edad promedio del sexo masculino?

# %%
grupoMaculino
# Out:
#        Unnamed: 0  age         workclass  fnlwgt     education  education-num  \
# 0               0   50  Self-emp-not-inc   83311     Bachelors             13
# 1               1   38           Private  215646       HS-grad              9
# 2               2   53           Private  234721          11th              7
# 6               6   52  Self-emp-not-inc  209642       HS-grad              9
# 8               8   42           Private  159449     Bachelors             13
# ...           ...  ...               ...     ...           ...            ...
# 32552       32552   32           Private  116138       Masters             14
# 32553       32553   53           Private  321865       Masters             14
# 32554       32554   22           Private  310152  Some-college             10
# 32556       32556   40           Private  154374       HS-grad              9
# 32558       32558   22           Private  201490       HS-grad              9
#
# ...

# %%
grupoMaculino["age"].mean()
# Out:
# 39.433567396392675

# %% [markdown]
# P4. ¿Cuál es la promoción de cubanos del dataset?

# %%
datos.columns
# Out:
# Index(['Unnamed: 0', 'age', 'workclass', 'fnlwgt', 'education',
#        'education-num', 'marital-status', 'occupation', 'relationship', 'race',
#        'sex', 'capital-gain', 'capital-loss', 'hours-per-week',
#        'native-country', 'salary'],
#       dtype='object')

# %%
datos["native-country"] == "Cuba"
# Out:
# 0        False
# 1        False
# 2        False
# 3         True
# 4        False
#          ...
# 32555    False
# 32556    False
# 32557    False
# 32558    False
# 32559    False
# Name: native-country, Length: 32560, dtype: bool

# %%
Cubanos = datos[datos["native-country"] == "Cuba"]
Cubanos
# Out:
#        Unnamed: 0  age         workclass  fnlwgt  education  education-num  \
# 3               3   28           Private  338409  Bachelors             13
# 80             80   52           Private  276515  Bachelors             13
# 637           637   47      Self-emp-inc  248145    5th-6th              3
# 700           700   31           Private  243605  Bachelors             13
# 1236         1236   41  Self-emp-not-inc  209344    HS-grad              9
# ...           ...  ...               ...     ...        ...            ...
# 30840       30840   37           Private  238433    1st-4th              2
# 30891       30891   52           Private  222646       12th              8
# 30905       30905   39  Self-emp-not-inc  251323        9th              5
# 31148       31148   52      Self-emp-inc  230767  Bachelors             13
# 31906       31906   48           Private  379883    Masters             14
#
# ...

# %%
Cubanos.shape
# 95 son Cubanos
# Out:
# (95, 16)

# %% [markdown]
# P5. ¿cuál es la edad promedio de aquellos que ganan más de 50K y menos de 50K?

# %%
gananmayora50k = datos[datos.salary == ">50K"]
gananmenora50k = datos[datos.salary == "<50K"]

# %%
gananmayora50k
# Out:
#        Unnamed: 0  age         workclass  fnlwgt     education  education-num  \
# 6               6   52  Self-emp-not-inc  209642       HS-grad              9
# 7               7   31           Private   45781       Masters             14
# 8               8   42           Private  159449     Bachelors             13
# 9               9   37           Private  280464  Some-college             10
# 10             10   30         State-gov  141297     Bachelors             13
# ...           ...  ...               ...     ...           ...            ...
# 32538       32538   71                 ?  287372     Doctorate             16
# 32544       32544   39         Local-gov  111499    Assoc-acdm             12
# 32553       32553   53           Private  321865       Masters             14
# 32556       32556   40           Private  154374       HS-grad              9
# 32559       32559   52      Self-emp-inc  287927       HS-grad              9
#
# ...

# %%
gananmenora50k
# Out:
# Empty DataFrame
# Columns: [Unnamed: 0, age, workclass, fnlwgt, education, education-num, marital-status, occupation, relationship, race, sex, capital-gain, capital-loss, hours-per-week, native-country, salary]
# Index: []

# %% [markdown]
# P6. Todos los que ganan más de 50k al año tienen master?

# %%
gananmayora50k
# Out:
#        Unnamed: 0  age         workclass  fnlwgt     education  education-num  \
# 6               6   52  Self-emp-not-inc  209642       HS-grad              9
# 7               7   31           Private   45781       Masters             14
# 8               8   42           Private  159449     Bachelors             13
# 9               9   37           Private  280464  Some-college             10
# 10             10   30         State-gov  141297     Bachelors             13
# ...           ...  ...               ...     ...           ...            ...
# 32538       32538   71                 ?  287372     Doctorate             16
# 32544       32544   39         Local-gov  111499    Assoc-acdm             12
# 32553       32553   53           Private  321865       Masters             14
# 32556       32556   40           Private  154374       HS-grad              9
# 32559       32559   52      Self-emp-inc  287927       HS-grad              9
#
# ...

# %%
type(gananmayora50k)
# Out:
# pandas.core.frame.DataFrame

# %%
Nomaster = gananmayora50k[gananmayora50k["education"] != "Masters"]

# %%
Nomaster["education"].count()
# Out:
# 6882

# %%
Simaster = gananmayora50k[gananmayora50k["education"] == "Masters"]

# %%
Simaster["education"].count()
# Out:
# 959

# %%
6882 + 959
# Out:
# 7841

# %% [markdown]
# DE LOS 7841 ENTREVISTADOS SOLO 959 SON MASTERS Y LOS 6882 SON NO MASTERS.
