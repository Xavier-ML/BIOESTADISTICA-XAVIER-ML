# %% [markdown]
# <a href="https://colab.research.google.com/github/Xavier-ML/BIOESTADISTICA-XAVIER-ML/blob/main/Dia_5_CIBERTEC.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Importación de Pandas

# %%
# Creación de data frames
dicx = {"nombre":["Anthony","Augusto","Iveth","Wilfredo","Javier","Rodrigo"],"apellidos":["Canales","Hinostroza","Rojas","Andia","Quispe","Urizar"],"edad":[30,20,39,40,25,31]}

# %%
import pandas as pd
base = pd.DataFrame(dicx)
base
# Out:
#      nombre   apellidos  edad
# 0   Anthony     Canales    30
# 1   Augusto  Hinostroza    20
# 2     Iveth       Rojas    39
# 3  Wilfredo       Andia    40
# 4    Javier      Quispe    25
# 5   Rodrigo      Urizar    31

# %%
lista = [["Anthony","Canales", 30],["Augusto","Hinostroza",40]]
columnas = ["Nombre", "Apellidos","Edad"]
base1 = pd.DataFrame(lista,columns=columnas)

# %%
type(base1)
# Out:
# pandas.core.frame.DataFrame

# %%
# pandas Read

tabla_csv = pd.read_csv("/content/hrdata.csv",sep=",")

# %%
tabla_csv.head(3)
# Out:
#              Name Hire Date   Salary  Sick Days remaining
# 0  Graham Chapman  03/15/14  50000.0                   10
# 1     John Cleese  06/01/15  65000.0                    8
# 2       Eric Idle  05/12/14  45000.0                   10

# %%
x = pd.read_excel("/content/Pruebaexcel.xlsx", sheet_name="A")

# %%
x.head
# Out:
# <bound method NDFrame.head of              Name            Hire Date  Salary  Sick Days remaining
# 0     Terry Jones  2013-01-11 00:00:00   70000                    3
# 1   Michael Palin             05/23/13   66000                    8
# 2     John Cleese  2015-01-06 00:00:00   65000                    8
# 3  Graham Chapman             03/15/14   50000                   10
# 4   Terry Gilliam  2014-12-08 00:00:00   48000                    7
# 5       Eric Idle  2014-12-05 00:00:00   45000                   10>

# %%
y = pd.read_excel("/content/Pruebaexcel.xlsx", sheet_name="B")

# %%
y.head
# Out:
# <bound method NDFrame.head of              Name  Edad
# 0     Terry Jones    24
# 1   Michael Palin    20
# 2     John Cleese    22
# 3  Graham Chapman    48
# 4   Terry Gilliam    42
# 5       Eric Idle    19>

# %%
x.shape
# Out:
# (6, 4)

# %%
y.shape
# Out:
# (6, 2)

# %%
x.tail()
# Out:
#              Name            Hire Date  Salary  Sick Days remaining
# 1   Michael Palin             05/23/13   66000                    8
# 2     John Cleese  2015-01-06 00:00:00   65000                    8
# 3  Graham Chapman             03/15/14   50000                   10
# 4   Terry Gilliam  2014-12-08 00:00:00   48000                    7
# 5       Eric Idle  2014-12-05 00:00:00   45000                   10

# %%
y.tail()
# Out:
#              Name  Edad
# 1   Michael Palin    20
# 2     John Cleese    22
# 3  Graham Chapman    48
# 4   Terry Gilliam    42
# 5       Eric Idle    19

# %%
x.dtypes
# Out:
# Name                   object
# Hire Date              object
# Salary                  int64
# Sick Days remaining     int64
# dtype: object

# %%
x["Sick Days remaining"] = x["Sick Days remaining"].astype("float64")

# %%
x.dtypes
# Out:
# Name                    object
# Hire Date               object
# Salary                   int64
# Sick Days remaining    float64
# dtype: object

# %%
m = pd.read_excel("/content/Ventas O.xlsx", sheet_name="BASE 1")

# %%
m.head()
# Out:
#    CODCLI  CODART           Repesentante                  Cliente    Pais  \
# 0       3       1  Fernando Gómez Garcia  DEPORTES REUNIDOS, S.L.  ESPAÑA
# 1       3       2  Fernando Gómez Garcia  DEPORTES REUNIDOS, S.L.  ESPAÑA
# 2       3       5  Fernando Gómez Garcia  DEPORTES REUNIDOS, S.L.  ESPAÑA
# 3       3       7  Fernando Gómez Garcia  DEPORTES REUNIDOS, S.L.  ESPAÑA
# 4       3      11  Fernando Gómez Garcia  DEPORTES REUNIDOS, S.L.  ESPAÑA
#
#   Comunidad autónoma Provincia    Zona                     Artículo  \
# 0             MADRID    MADRID  Centro            Bicicleta carrera
# 1             MADRID    MADRID  Centro  Bicicleta mountain infantil
# 2             MADRID    MADRID  Centro     Bicicleta carrera mod. B
# 3             MADRID    MADRID  Centro                Mountain bike
# 4             MADRID    MADRID  Centro   Bicicleta carrera modelo C
#
#        Fecha  Trimestre  Mes Característica 1 cliente  \
# ...

# %%
m.tail()
# Out:
#       CODCLI  CODART           Repesentante                   Cliente    Pais  \
# 2094      20       9    Juanjo Pérez Romero  DEPORTES DE RUEDAS, S.L.  ESPAÑA
# 2095       1       3  Fernando Gómez Garcia                SPORTS ABC  ESPAÑA
# 2096       1       9  Fernando Gómez Garcia                SPORTS ABC  ESPAÑA
# 2097       2       3    Juanjo Pérez Romero              SPORTI, S.A.  ESPAÑA
# 2098       2       9    Juanjo Pérez Romero              SPORTI, S.A.  ESPAÑA
#
#      Comunidad autónoma  Provincia    Zona                 Artículo  \
# 2094      CASTILLA-LEON      AVILA  Centro  Bicicleta tres asientos
# 2095          CATALUNYA  BARCELONA    Este           Bicicleta dual
# 2096          CATALUNYA  BARCELONA    Este  Bicicleta tres asientos
# 2097          CATALUNYA  BARCELONA    Este           Bicicleta dual
# 2098          CATALUNYA  BARCELONA    Este  Bicicleta tres asientos
#
#           Fecha  Trimestre  Mes Característica 1 cliente  \
# ...

# %%
m.shape
# Out:
# (2099, 17)

# %%
m.dtypes
# Out:
# CODCLI                                int64
# CODART                                int64
# Repesentante                         object
# Cliente                              object
# Pais                                 object
# Comunidad autónoma                   object
# Provincia                            object
# Zona                                 object
# Artículo                             object
# Fecha                        datetime64[ns]
# Trimestre                             int64
# Mes                                   int64
# Característica 1 cliente             object
# Característica 1 artículo            object
# Neto                                  int64
# Bruto                               float64
# Cantidades                            int64
# dtype: object

# %%
m =m.astype({"CODCLI":"object","CODART":"object","Bruto":"float64","Mes":"object","Trimestre":"object"})

# %%
m.dtypes
# Out:
# CODCLI                               object
# CODART                               object
# Repesentante                         object
# Cliente                              object
# Pais                                 object
# Comunidad autónoma                   object
# Provincia                            object
# Zona                                 object
# Artículo                             object
# Fecha                        datetime64[ns]
# Trimestre                            object
# Mes                                  object
# Característica 1 cliente             object
# Característica 1 artículo            object
# Neto                                  int64
# Bruto                               float64
# Cantidades                            int64
# dtype: object

# %%
m.columns
# Out:
# Index(['CODCLI', 'CODART', 'Repesentante', 'Cliente', 'Pais',
#        'Comunidad autónoma', 'Provincia', 'Zona', 'Artículo', 'Fecha',
#        'Trimestre', 'Mes', 'Característica 1 cliente',
#        'Característica 1 artículo', 'Neto', 'Bruto', 'Cantidades'],
#       dtype='object')

# %%
m.describe()
# Out:
#                Neto        Bruto   Cantidades
# count   2099.000000  2099.000000  2099.000000
# mean    5932.763221  5042.848737   256.172939
# std     2870.747533  2440.135403   143.216117
# min     1000.000000   850.000000     5.000000
# 25%     3430.500000  2915.925000   132.000000
# 50%     5817.000000  4944.450000   260.000000
# 75%     8529.500000  7250.075000   380.000000
# max    10993.000000  9344.050000   500.000000

# %%
m.columns
# Out:
# Index(['CODCLI', 'CODART', 'Repesentante', 'Cliente', 'Pais',
#        'Comunidad autónoma', 'Provincia', 'Zona', 'Artículo', 'Fecha',
#        'Trimestre', 'Mes', 'Característica 1 cliente',
#        'Característica 1 artículo', 'Neto', 'Bruto', 'Cantidades'],
#       dtype='object')

# %%
for i in m.columns:
    print(i)
# Out:
# CODCLI
# CODART
# Repesentante
# Cliente
# Pais
# Comunidad autónoma
# Provincia
# Zona
# Artículo
# Fecha
# Trimestre
# Mes
# Característica 1 cliente
# Característica 1 artículo
# Neto
# Bruto
# Cantidades

# %%
m["Zona"].head()
# Out:
# 0    Centro
# 1    Centro
# 2    Centro
# 3    Centro
# 4    Centro
# Name: Zona, dtype: object

# %%
x['Name'].head()
# Out:
# 0       Terry Jones
# 1     Michael Palin
# 2       John Cleese
# 3    Graham Chapman
# 4     Terry Gilliam
# Name: Name, dtype: object

# %%
lista = ['Name','Salary']
x[lista].head()
# Out:
#              Name  Salary
# 0     Terry Jones   70000
# 1   Michael Palin   66000
# 2     John Cleese   65000
# 3  Graham Chapman   50000
# 4   Terry Gilliam   48000

# %%
x.index
# Out:
# RangeIndex(start=0, stop=6, step=1)

# %%
x.loc[4]
# Out:
# Name                         Terry Gilliam
# Hire Date              2014-12-08 00:00:00
# Salary                               48000
# Sick Days remaining                    7.0
# Name: 4, dtype: object

# %%
n = x.set_index('Name').copy()

# %%
n
# Out:
#                           Hire Date  Salary  Sick Days remaining
# Name
# Terry Jones     2013-01-11 00:00:00   70000                  3.0
# Michael Palin              05/23/13   66000                  8.0
# John Cleese     2015-01-06 00:00:00   65000                  8.0
# Graham Chapman             03/15/14   50000                 10.0
# Terry Gilliam   2014-12-08 00:00:00   48000                  7.0
# Eric Idle       2014-12-05 00:00:00   45000                 10.0

# %%
n.loc['Terry Jones']
# Out:
# Hire Date              2013-01-11 00:00:00
# Salary                               70000
# Sick Days remaining                    3.0
# Name: Terry Jones, dtype: object

# %%
n.loc[0]
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# /usr/local/lib/python3.10/dist-packages/pandas/core/indexes/base.py in get_loc(self, key, method, tolerance)
#    3801             try:
# -> 3802                 return self._engine.get_loc(casted_key)
#    3803             except KeyError as err:
#
# /usr/local/lib/python3.10/dist-packages/pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# /usr/local/lib/python3.10/dist-packages/pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 0
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# ...

# %%
n = x.set_index('Salary').copy()

# %%
n.loc[50000]
# Out:
# Name                   Graham Chapman
# Hire Date                    03/15/14
# Sick Days remaining              10.0
# Name: 50000, dtype: object

# %%
x.head()
# Out:
#              Name            Hire Date  Salary  Sick Days remaining
# 0     Terry Jones  2013-01-11 00:00:00   70000                  3.0
# 1   Michael Palin             05/23/13   66000                  8.0
# 2     John Cleese  2015-01-06 00:00:00   65000                  8.0
# 3  Graham Chapman             03/15/14   50000                 10.0
# 4   Terry Gilliam  2014-12-08 00:00:00   48000                  7.0

# %%
condicion = x['Salary'] >= 50000

# %%
condicion
# Out:
# 0     True
# 1     True
# 2     True
# 3     True
# 4    False
# 5    False
# Name: Salary, dtype: bool

# %%
x[x.Salary >= 50000]
# Out:
#              Name            Hire Date  Salary  Sick Days remaining
# 0     Terry Jones  2013-01-11 00:00:00   70000                  3.0
# 1   Michael Palin             05/23/13   66000                  8.0
# 2     John Cleese  2015-01-06 00:00:00   65000                  8.0
# 3  Graham Chapman             03/15/14   50000                 10.0

# %%
x[(x['Sick Days remaining'] > 2) & ~(x.Salary == 70000)]
# Out:
#              Name            Hire Date  Salary  Sick Days remaining
# 1   Michael Palin             05/23/13   66000                  8.0
# 2     John Cleese  2015-01-06 00:00:00   65000                  8.0
# 3  Graham Chapman             03/15/14   50000                 10.0
# 4   Terry Gilliam  2014-12-08 00:00:00   48000                  7.0
# 5       Eric Idle  2014-12-05 00:00:00   45000                 10.0
