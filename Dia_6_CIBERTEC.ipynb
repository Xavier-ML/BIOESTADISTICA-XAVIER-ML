# %% [markdown]
# <a href="https://colab.research.google.com/github/Xavier-ML/BIOESTADISTICA-XAVIER-ML/blob/main/Dia_6_CIBERTEC.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd

# %%
peru = [["Paolo","Guerrero", 39],["Pedro","Gallese",11],["Aldo","Corzo",34],["Wilfredo","Andia",31],["Andre","Crrillo",29],["Julio","Ramos",33],["Alexis","Arias",27],["Edision","Flores",29]]

# %%
titulos = ["Nombre","Apellido","Edad"]

# %%
base = pd.DataFrame(peru, columns=titulos)

# %%
base
# Out:
#      Nombre  Apellido  Edad
# 0     Paolo  Guerrero    39
# 1     Pedro   Gallese    11
# 2      Aldo     Corzo    34
# 3  Wilfredo     Andia    31
# 4     Andre   Crrillo    29
# 5     Julio     Ramos    33
# 6    Alexis     Arias    27
# 7   Edision    Flores    29
#      Nombre  Apellido  Edad
# 0     Paolo  Guerrero    39
# 1     Pedro   Gallese    11
# 2      Aldo     Corzo    34
# 3  Wilfredo     Andia    31
# 4     Andre   Crrillo    29
# 5     Julio     Ramos    33
# 6    Alexis     Arias    27
# 7   Edision    Flores    29

# %%
base.shape
# Out:
# (8, 3)
# (8, 3)

# %%
type(base)
# Out:
# pandas.core.frame.DataFrame
# pandas.core.frame.DataFrame

# %%
base.head(1)
# Out:
#   Nombre  Apellido  Edad
# 0  Paolo  Guerrero    39
#   Nombre  Apellido  Edad
# 0  Paolo  Guerrero    39

# %%
base.tail(1)
# Out:
#     Nombre Apellido  Edad
# 7  Edision   Flores    29
#     Nombre Apellido  Edad
# 7  Edision   Flores    29

# %%
# tipo de dato por columnas se usa dtypes
base.dtypes
# Out:
# Nombre      object
# Apellido    object
# Edad         int64
# dtype: object
# Nombre      object
# Apellido    object
# Edad         int64
# dtype: object

# %%
# como cambiar el tipo de dato astype
base.Edad = base.Edad.astype("float64")

# %%
# estadistico de la tabla usar describe
base.describe()
# Out:
#             Edad
# count   8.000000
# mean   29.125000
# std     8.219098
# min    11.000000
# 25%    28.500000
# 50%    30.000000
# 75%    33.250000
# max    39.000000
#             Edad
# count   8.000000
# mean   29.125000
# std     8.219098
# min    11.000000
# 25%    28.500000
# 50%    30.000000
# 75%    33.250000
# max    39.000000

# %%
base.Nombre.head()
# Out:
# 0       Paolo
# 1       Pedro
# 2        Aldo
# 3    Wilfredo
# 4       Andre
# Name: Nombre, dtype: object
# 0       Paolo
# 1       Pedro
# 2        Aldo
# 3    Wilfredo
# 4       Andre
# Name: Nombre, dtype: object

# %%
lista = ["Nombre", "Apellido"]

# %%
lista
# Out:
# ['Nombre', 'Apellido']
# ['Nombre', 'Apellido']

# %%
base.Nombre[1:3]
# Out:
# 1    Pedro
# 2     Aldo
# Name: Nombre, dtype: object
# 1    Pedro
# 2     Aldo
# Name: Nombre, dtype: object

# %%
base.index
# Out:
# RangeIndex(start=0, stop=8, step=1)
# RangeIndex(start=0, stop=8, step=1)

# %%
base.loc[3]
# Out:
# Nombre      Wilfredo
# Apellido       Andia
# Edad            31.0
# Name: 3, dtype: object
# Nombre      Wilfredo
# Apellido       Andia
# Edad            31.0
# Name: 3, dtype: object

# %%
base.iloc[5]
# Out:
# Nombre      Julio
# Apellido    Ramos
# Edad         33.0
# Name: 5, dtype: object

# %%
base[base.Edad >= 35]
# Out:
#   Nombre  Apellido  Edad
# 0  Paolo  Guerrero  39.0

# %%
base[(base.Edad < 35) & base.Apellido.apply(lambda x:x[0:1] not in "AEIOU")]
# Out:
#     Nombre Apellido  Edad
# 1    Pedro  Gallese  11.0
# 2     Aldo    Corzo  34.0
# 4    Andre  Crrillo  29.0
# 5    Julio    Ramos  33.0
# 7  Edision   Flores  29.0

# %%
peru = [["Paolo","Guerrero", 39,56,1.8],["Pedro","Gallese",11,67,1.9],["Aldo","Corzo",34,45,1.7],["Wilfredo","Andia",31,60,1.67],["Andre","Crrillo",29,70,1.69],["Julio","Ramos",33,80,1.6],["Alexis","Arias",27,55,1.8],["Edision","Flores",29,66,1.8]]

# %%
titulos = ["Nombre","Apellido","Edad","Peso","Talla"]

# %%
jugadores = pd.DataFrame(peru, columns=titulos)

# %%
jugadores
# Out:
#      Nombre  Apellido  Edad  Peso  Talla
# 0     Paolo  Guerrero    39    56   1.80
# 1     Pedro   Gallese    11    67   1.90
# 2      Aldo     Corzo    34    45   1.70
# 3  Wilfredo     Andia    31    60   1.67
# 4     Andre   Crrillo    29    70   1.69
# 5     Julio     Ramos    33    80   1.60
# 6    Alexis     Arias    27    55   1.80
# 7   Edision    Flores    29    66   1.80

# %%
jugadores["IMC"] = jugadores.Peso/jugadores.Talla**2

# %%
jugadores
# Out:
#      Nombre  Apellido  Edad  Peso  Talla        IMC
# 0     Paolo  Guerrero    39    56   1.80  17.283951
# 1     Pedro   Gallese    11    67   1.90  18.559557
# 2      Aldo     Corzo    34    45   1.70  15.570934
# 3  Wilfredo     Andia    31    60   1.67  21.513859
# 4     Andre   Crrillo    29    70   1.69  24.508946
# 5     Julio     Ramos    33    80   1.60  31.250000
# 6    Alexis     Arias    27    55   1.80  16.975309
# 7   Edision    Flores    29    66   1.80  20.370370

# %%
jugadores["Nombre compuesto"] = jugadores.Nombre + " " + jugadores.Apellido

# %%
jugadores
# Out:
#      Nombre  Apellido  Edad  Peso  Talla        IMC Nombre compuesto
# 0     Paolo  Guerrero    39    56   1.80  17.283951  Paolo  Guerrero
# 1     Pedro   Gallese    11    67   1.90  18.559557   Pedro  Gallese
# 2      Aldo     Corzo    34    45   1.70  15.570934      Aldo  Corzo
# 3  Wilfredo     Andia    31    60   1.67  21.513859  Wilfredo  Andia
# 4     Andre   Crrillo    29    70   1.69  24.508946   Andre  Crrillo
# 5     Julio     Ramos    33    80   1.60  31.250000     Julio  Ramos
# 6    Alexis     Arias    27    55   1.80  16.975309    Alexis  Arias
# 7   Edision    Flores    29    66   1.80  20.370370  Edision  Flores

# %%
jugadores["Suma edad y peso"] = jugadores.Edad + jugadores.Peso

# %%
jugadores
# Out:
#      Nombre  Apellido  Edad  Peso  Talla        IMC Nombre compuesto  \
# 0     Paolo  Guerrero    39    56   1.80  17.283951  Paolo  Guerrero
# 1     Pedro   Gallese    11    67   1.90  18.559557   Pedro  Gallese
# 2      Aldo     Corzo    34    45   1.70  15.570934      Aldo  Corzo
# 3  Wilfredo     Andia    31    60   1.67  21.513859  Wilfredo  Andia
# 4     Andre   Crrillo    29    70   1.69  24.508946   Andre  Crrillo
# 5     Julio     Ramos    33    80   1.60  31.250000     Julio  Ramos
# 6    Alexis     Arias    27    55   1.80  16.975309    Alexis  Arias
# 7   Edision    Flores    29    66   1.80  20.370370  Edision  Flores
#
#    Suma edad y peso
# 0                95
# 1                78
# 2                79
# 3                91
# 4                99
# 5               113
# 6                82
# 7                95

# %%
orden = jugadores.sort_values(by=["Nombre","Edad"],ascending=[False,True])

# %%
lista2 = ["Nombre","Edad"]
orden[lista2].head(10)
# Out:
#      Nombre  Edad
# 3  Wilfredo    31
# 1     Pedro    11
# 0     Paolo    39
# 5     Julio    33
# 7   Edision    29
# 4     Andre    29
# 6    Alexis    27
# 2      Aldo    34

# %%
orden2 = jugadores.sort_values(by=["Edad"],ascending=[True])

# %%
orden2
# Out:
#      Nombre  Apellido  Edad  Peso  Talla        IMC Nombre compuesto  \
# 1     Pedro   Gallese    11    67   1.90  18.559557   Pedro  Gallese
# 6    Alexis     Arias    27    55   1.80  16.975309    Alexis  Arias
# 4     Andre   Crrillo    29    70   1.69  24.508946   Andre  Crrillo
# 7   Edision    Flores    29    66   1.80  20.370370  Edision  Flores
# 3  Wilfredo     Andia    31    60   1.67  21.513859  Wilfredo  Andia
# 5     Julio     Ramos    33    80   1.60  31.250000     Julio  Ramos
# 2      Aldo     Corzo    34    45   1.70  15.570934      Aldo  Corzo
# 0     Paolo  Guerrero    39    56   1.80  17.283951  Paolo  Guerrero
#
#    Suma edad y peso
# 1                78
# 6                82
# 4                99
# 7                95
# 3                91
# 5               113
# 2                79
# 0                95

# %%
ventas = pd.read_excel("/content/Ventas O.xlsx", sheet_name=)

# %% [markdown]
# # Nueva sección
